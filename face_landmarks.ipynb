# %%
import mediapipe as mp
import cv2

# %%
mp_face=mp.solutions.face_detection
mp_drawing=mp.solutions.drawing_utils

# %%
face_dt=mp_face.FaceDetection()

# %%
video=cv2.VideoCapture(0)
while True:
    suc,img=video.read()
    img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    result=face_dt.process(img1)
    print(result.detections)
    if result.detections:
        for det in result.detections:
            mp_drawing.draw_detection(img,det)

    cv2.imshow('WEBCAM',img)
    if cv2.waitKey(1) & 0XFF==ord('q'):
        break
video.release()
cv2.destroyAllWindows()
# Out:
# None
# [label_id: 0
# score: 0.6872714
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.45242986
#     ymin: 0.37079048
#     width: 0.20570645
#     height: 0.27427417
#   }
#   relative_keypoints {
#     x: 0.5007255
#     y: 0.49019772
#   }
#   relative_keypoints {
#     x: 0.57904166
#     y: 0.47280437
#   }
#   relative_keypoints {
#     x: 0.5430639
#     y: 0.56257135
#   }
#   relative_keypoints {
#     x: 0.55404687
#     y: 0.59892493
#   }
#   relative_keypoints {
#     x: 0.47000656
#     y: 0.47099918
#   }
#   relative_keypoints {
#     x: 0.643903
#     y: 0.43039882
#   }
# }
# ]
# [label_id: 0
# score: 0.6872714
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.45242986
#     ymin: 0.37079048
#     width: 0.20570645
#     height: 0.27427417
#   }
#   relative_keypoints {
#     x: 0.5007255
#     y: 0.49019772
#   }
#   relative_keypoints {
#     x: 0.57904166
#     y: 0.47280437
#   }
#   relative_keypoints {
#     x: 0.5430639
#     y: 0.56257135
#   }
#   relative_keypoints {
#     x: 0.55404687
#     y: 0.59892493
#   }
#   relative_keypoints {
#     x: 0.47000656
#     y: 0.47099918
#   }
#   relative_keypoints {
#     x: 0.643903
#     y: 0.43039882
#   }
# }
# ]
# [label_id: 0
# score: 0.6872714
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.45242986
#     ymin: 0.37079048
#     width: 0.20570645
#     height: 0.27427417
#   }
#   relative_keypoints {
#     x: 0.5007255
#     y: 0.49019772
#   }
#   relative_keypoints {
#     x: 0.57904166
#     y: 0.47280437
#   }
#   relative_keypoints {
#     x: 0.5430639
#     y: 0.56257135
#   }
#   relative_keypoints {
#     x: 0.55404687
#     y: 0.59892493
#   }
#   relative_keypoints {
#     x: 0.47000656
#     y: 0.47099918
#   }
#   relative_keypoints {
#     x: 0.643903
#     y: 0.43039882
#   }
# }
# ]
# [label_id: 0
# score: 0.6872714
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.45242986
#     ymin: 0.37079048
#     width: 0.20570645
#     height: 0.27427417
#   }
#   relative_keypoints {
#     x: 0.5007255
#     y: 0.49019772
#   }
#   relative_keypoints {
#     x: 0.57904166
#     y: 0.47280437
#   }
#   relative_keypoints {
#     x: 0.5430639
#     y: 0.56257135
#   }
#   relative_keypoints {
#     x: 0.55404687
#     y: 0.59892493
#   }
#   relative_keypoints {
#     x: 0.47000656
#     y: 0.47099918
#   }
#   relative_keypoints {
#     x: 0.643903
#     y: 0.43039882
#   }
# }
# ]
# [label_id: 0
# score: 0.88934803
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.44125187
#     ymin: 0.36659342
#     width: 0.20639151
#     height: 0.27518845
#   }
#   relative_keypoints {
#     x: 0.4788596
#     y: 0.46611553
#   }
#   relative_keypoints {
#     x: 0.56446
#     y: 0.44889832
#   }
#   relative_keypoints {
#     x: 0.52000666
#     y: 0.5311532
#   }
#   relative_keypoints {
#     x: 0.5336412
#     y: 0.5787182
#   }
#   relative_keypoints {
#     x: 0.4545667
#     y: 0.4786709
#   }
#   relative_keypoints {
#     x: 0.6413515
#     y: 0.43647087
#   }
# }
# ]
# [label_id: 0
# score: 0.88934803
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.44125187
#     ymin: 0.36659342
#     width: 0.20639151
#     height: 0.27518845
#   }
#   relative_keypoints {
#     x: 0.4788596
#     y: 0.46611553
#   }
#   relative_keypoints {
#     x: 0.56446
#     y: 0.44889832
#   }
#   relative_keypoints {
#     x: 0.52000666
#     y: 0.5311532
#   }
#   relative_keypoints {
#     x: 0.5336412
#     y: 0.5787182
#   }
#   relative_keypoints {
#     x: 0.4545667
#     y: 0.4786709
#   }
#   relative_keypoints {
#     x: 0.6413515
#     y: 0.43647087
#   }
# }
# ]
# [label_id: 0
# score: 0.88934803
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.44125187
#     ymin: 0.36659342
#     width: 0.20639151
#     height: 0.27518845
#   }
#   relative_keypoints {
#     x: 0.4788596
#     y: 0.46611553
#   }
#   relative_keypoints {
#     x: 0.56446
#     y: 0.44889832
#   }
#   relative_keypoints {
#     x: 0.52000666
#     y: 0.5311532
#   }
#   relative_keypoints {
#     x: 0.5336412
#     y: 0.5787182
#   }
#   relative_keypoints {
#     x: 0.4545667
#     y: 0.4786709
#   }
#   relative_keypoints {
#     x: 0.6413515
#     y: 0.43647087
#   }
# }
# ]
# [label_id: 0
# score: 0.88934803
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.44125187
#     ymin: 0.36659342
#     width: 0.20639151
#     height: 0.27518845
#   }
#   relative_keypoints {
#     x: 0.4788596
#     y: 0.46611553
#   }
#   relative_keypoints {
#     x: 0.56446
#     y: 0.44889832
#   }
#   relative_keypoints {
#     x: 0.52000666
#     y: 0.5311532
#   }
#   relative_keypoints {
#     x: 0.5336412
#     y: 0.5787182
#   }
#   relative_keypoints {
#     x: 0.4545667
#     y: 0.4786709
#   }
#   relative_keypoints {
#     x: 0.6413515
#     y: 0.43647087
#   }
# }
# ]
# [label_id: 0
# score: 0.8392463
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41631252
#     ymin: 0.35184032
#     width: 0.22378302
#     height: 0.29837698
#   }
#   relative_keypoints {
#     x: 0.46965256
#     y: 0.46016556
#   }
#   relative_keypoints {
#     x: 0.56487525
#     y: 0.4493162
#   }
#   relative_keypoints {
#     x: 0.5190464
#     y: 0.5391734
#   }
#   relative_keypoints {
#     x: 0.52527744
#     y: 0.58822674
#   }
#   relative_keypoints {
#     x: 0.42518097
#     y: 0.46195626
#   }
#   relative_keypoints {
#     x: 0.62986785
#     y: 0.4357217
#   }
# }
# ]
# [label_id: 0
# score: 0.8392463
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41631252
#     ymin: 0.35184032
#     width: 0.22378302
#     height: 0.29837698
#   }
#   relative_keypoints {
#     x: 0.46965256
#     y: 0.46016556
#   }
#   relative_keypoints {
#     x: 0.56487525
#     y: 0.4493162
#   }
#   relative_keypoints {
#     x: 0.5190464
#     y: 0.5391734
#   }
#   relative_keypoints {
#     x: 0.52527744
#     y: 0.58822674
#   }
#   relative_keypoints {
#     x: 0.42518097
#     y: 0.46195626
#   }
#   relative_keypoints {
#     x: 0.62986785
#     y: 0.4357217
#   }
# }
# ]
# [label_id: 0
# score: 0.8392463
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41631252
#     ymin: 0.35184032
#     width: 0.22378302
#     height: 0.29837698
#   }
#   relative_keypoints {
#     x: 0.46965256
#     y: 0.46016556
#   }
#   relative_keypoints {
#     x: 0.56487525
#     y: 0.4493162
#   }
#   relative_keypoints {
#     x: 0.5190464
#     y: 0.5391734
#   }
#   relative_keypoints {
#     x: 0.52527744
#     y: 0.58822674
#   }
#   relative_keypoints {
#     x: 0.42518097
#     y: 0.46195626
#   }
#   relative_keypoints {
#     x: 0.62986785
#     y: 0.4357217
#   }
# }
# ]
# [label_id: 0
# score: 0.8392463
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41631252
#     ymin: 0.35184032
#     width: 0.22378302
#     height: 0.29837698
#   }
#   relative_keypoints {
#     x: 0.46965256
#     y: 0.46016556
#   }
#   relative_keypoints {
#     x: 0.56487525
#     y: 0.4493162
#   }
#   relative_keypoints {
#     x: 0.5190464
#     y: 0.5391734
#   }
#   relative_keypoints {
#     x: 0.52527744
#     y: 0.58822674
#   }
#   relative_keypoints {
#     x: 0.42518097
#     y: 0.46195626
#   }
#   relative_keypoints {
#     x: 0.62986785
#     y: 0.4357217
#   }
# }
# ]
# [label_id: 0
# score: 0.8957187
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4029098
#     ymin: 0.34905964
#     width: 0.2330142
#     height: 0.31068575
#   }
#   relative_keypoints {
#     x: 0.4696011
#     y: 0.4558741
#   }
#   relative_keypoints {
#     x: 0.56880325
#     y: 0.43159485
#   }
#   relative_keypoints {
#     x: 0.53549564
#     y: 0.51982
#   }
#   relative_keypoints {
#     x: 0.54301494
#     y: 0.57924247
#   }
#   relative_keypoints {
#     x: 0.40984374
#     y: 0.48948252
#   }
#   relative_keypoints {
#     x: 0.62296647
#     y: 0.4323287
#   }
# }
# ]
# [label_id: 0
# score: 0.8957187
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4029098
#     ymin: 0.34905964
#     width: 0.2330142
#     height: 0.31068575
#   }
#   relative_keypoints {
#     x: 0.4696011
#     y: 0.4558741
#   }
#   relative_keypoints {
#     x: 0.56880325
#     y: 0.43159485
#   }
#   relative_keypoints {
#     x: 0.53549564
#     y: 0.51982
#   }
#   relative_keypoints {
#     x: 0.54301494
#     y: 0.57924247
#   }
#   relative_keypoints {
#     x: 0.40984374
#     y: 0.48948252
#   }
#   relative_keypoints {
#     x: 0.62296647
#     y: 0.4323287
#   }
# }
# ]
# [label_id: 0
# score: 0.8957187
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4029098
#     ymin: 0.34905964
#     width: 0.2330142
#     height: 0.31068575
#   }
#   relative_keypoints {
#     x: 0.4696011
#     y: 0.4558741
#   }
#   relative_keypoints {
#     x: 0.56880325
#     y: 0.43159485
#   }
#   relative_keypoints {
#     x: 0.53549564
#     y: 0.51982
#   }
#   relative_keypoints {
#     x: 0.54301494
#     y: 0.57924247
#   }
#   relative_keypoints {
#     x: 0.40984374
#     y: 0.48948252
#   }
#   relative_keypoints {
#     x: 0.62296647
#     y: 0.4323287
#   }
# }
# ]
# [label_id: 0
# score: 0.8957187
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4029098
#     ymin: 0.34905964
#     width: 0.2330142
#     height: 0.31068575
#   }
#   relative_keypoints {
#     x: 0.4696011
#     y: 0.4558741
#   }
#   relative_keypoints {
#     x: 0.56880325
#     y: 0.43159485
#   }
#   relative_keypoints {
#     x: 0.53549564
#     y: 0.51982
#   }
#   relative_keypoints {
#     x: 0.54301494
#     y: 0.57924247
#   }
#   relative_keypoints {
#     x: 0.40984374
#     y: 0.48948252
#   }
#   relative_keypoints {
#     x: 0.62296647
#     y: 0.4323287
#   }
# }
# ]
# [label_id: 0
# score: 0.87634295
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40787074
#     ymin: 0.34570426
#     width: 0.23546317
#     height: 0.31395054
#   }
#   relative_keypoints {
#     x: 0.46470544
#     y: 0.45572114
#   }
#   relative_keypoints {
#     x: 0.56774724
#     y: 0.42565757
#   }
#   relative_keypoints {
#     x: 0.52708435
#     y: 0.518513
#   }
#   relative_keypoints {
#     x: 0.53880334
#     y: 0.5792594
#   }
#   relative_keypoints {
#     x: 0.41554812
#     y: 0.49108857
#   }
#   relative_keypoints {
#     x: 0.63416284
#     y: 0.42569733
#   }
# }
# ]
# [label_id: 0
# score: 0.87634295
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40787074
#     ymin: 0.34570426
#     width: 0.23546317
#     height: 0.31395054
#   }
#   relative_keypoints {
#     x: 0.46470544
#     y: 0.45572114
#   }
#   relative_keypoints {
#     x: 0.56774724
#     y: 0.42565757
#   }
#   relative_keypoints {
#     x: 0.52708435
#     y: 0.518513
#   }
#   relative_keypoints {
#     x: 0.53880334
#     y: 0.5792594
#   }
#   relative_keypoints {
#     x: 0.41554812
#     y: 0.49108857
#   }
#   relative_keypoints {
#     x: 0.63416284
#     y: 0.42569733
#   }
# }
# ]
# [label_id: 0
# score: 0.87634295
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40787074
#     ymin: 0.34570426
#     width: 0.23546317
#     height: 0.31395054
#   }
#   relative_keypoints {
#     x: 0.46470544
#     y: 0.45572114
#   }
#   relative_keypoints {
#     x: 0.56774724
#     y: 0.42565757
#   }
#   relative_keypoints {
#     x: 0.52708435
#     y: 0.518513
#   }
#   relative_keypoints {
#     x: 0.53880334
#     y: 0.5792594
#   }
#   relative_keypoints {
#     x: 0.41554812
#     y: 0.49108857
#   }
#   relative_keypoints {
#     x: 0.63416284
#     y: 0.42569733
#   }
# }
# ]
# [label_id: 0
# score: 0.87634295
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40787074
#     ymin: 0.34570426
#     width: 0.23546317
#     height: 0.31395054
#   }
#   relative_keypoints {
#     x: 0.46470544
#     y: 0.45572114
#   }
#   relative_keypoints {
#     x: 0.56774724
#     y: 0.42565757
#   }
#   relative_keypoints {
#     x: 0.52708435
#     y: 0.518513
#   }
#   relative_keypoints {
#     x: 0.53880334
#     y: 0.5792594
#   }
#   relative_keypoints {
#     x: 0.41554812
#     y: 0.49108857
#   }
#   relative_keypoints {
#     x: 0.63416284
#     y: 0.42569733
#   }
# }
# ]
# [label_id: 0
# score: 0.87121993
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40680063
#     ymin: 0.3365404
#     width: 0.2409085
#     height: 0.32121122
#   }
#   relative_keypoints {
#     x: 0.46818116
#     y: 0.44431
#   }
#   relative_keypoints {
#     x: 0.5742561
#     y: 0.41911584
#   }
#   relative_keypoints {
#     x: 0.5326148
#     y: 0.50838715
#   }
#   relative_keypoints {
#     x: 0.5423868
#     y: 0.57201785
#   }
#   relative_keypoints {
#     x: 0.41415215
#     y: 0.48206812
#   }
#   relative_keypoints {
#     x: 0.6387657
#     y: 0.42554802
#   }
# }
# ]
# [label_id: 0
# score: 0.87121993
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40680063
#     ymin: 0.3365404
#     width: 0.2409085
#     height: 0.32121122
#   }
#   relative_keypoints {
#     x: 0.46818116
#     y: 0.44431
#   }
#   relative_keypoints {
#     x: 0.5742561
#     y: 0.41911584
#   }
#   relative_keypoints {
#     x: 0.5326148
#     y: 0.50838715
#   }
#   relative_keypoints {
#     x: 0.5423868
#     y: 0.57201785
#   }
#   relative_keypoints {
#     x: 0.41415215
#     y: 0.48206812
#   }
#   relative_keypoints {
#     x: 0.6387657
#     y: 0.42554802
#   }
# }
# ]
# [label_id: 0
# score: 0.87121993
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40680063
#     ymin: 0.3365404
#     width: 0.2409085
#     height: 0.32121122
#   }
#   relative_keypoints {
#     x: 0.46818116
#     y: 0.44431
#   }
#   relative_keypoints {
#     x: 0.5742561
#     y: 0.41911584
#   }
#   relative_keypoints {
#     x: 0.5326148
#     y: 0.50838715
#   }
#   relative_keypoints {
#     x: 0.5423868
#     y: 0.57201785
#   }
#   relative_keypoints {
#     x: 0.41415215
#     y: 0.48206812
#   }
#   relative_keypoints {
#     x: 0.6387657
#     y: 0.42554802
#   }
# }
# ]
# [label_id: 0
# score: 0.87121993
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40680063
#     ymin: 0.3365404
#     width: 0.2409085
#     height: 0.32121122
#   }
#   relative_keypoints {
#     x: 0.46818116
#     y: 0.44431
#   }
#   relative_keypoints {
#     x: 0.5742561
#     y: 0.41911584
#   }
#   relative_keypoints {
#     x: 0.5326148
#     y: 0.50838715
#   }
#   relative_keypoints {
#     x: 0.5423868
#     y: 0.57201785
#   }
#   relative_keypoints {
#     x: 0.41415215
#     y: 0.48206812
#   }
#   relative_keypoints {
#     x: 0.6387657
#     y: 0.42554802
#   }
# }
# ]
# [label_id: 0
# score: 0.89195544
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40953335
#     ymin: 0.3162145
#     width: 0.2462295
#     height: 0.32830578
#   }
#   relative_keypoints {
#     x: 0.48245844
#     y: 0.4067518
#   }
#   relative_keypoints {
#     x: 0.5947485
#     y: 0.39637262
#   }
#   relative_keypoints {
#     x: 0.5520815
#     y: 0.46938968
#   }
#   relative_keypoints {
#     x: 0.553694
#     y: 0.543948
#   }
#   relative_keypoints {
#     x: 0.41072148
#     y: 0.4561959
#   }
#   relative_keypoints {
#     x: 0.64698094
#     y: 0.42878473
#   }
# }
# ]
# [label_id: 0
# score: 0.89195544
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40953335
#     ymin: 0.3162145
#     width: 0.2462295
#     height: 0.32830578
#   }
#   relative_keypoints {
#     x: 0.48245844
#     y: 0.4067518
#   }
#   relative_keypoints {
#     x: 0.5947485
#     y: 0.39637262
#   }
#   relative_keypoints {
#     x: 0.5520815
#     y: 0.46938968
#   }
#   relative_keypoints {
#     x: 0.553694
#     y: 0.543948
#   }
#   relative_keypoints {
#     x: 0.41072148
#     y: 0.4561959
#   }
#   relative_keypoints {
#     x: 0.64698094
#     y: 0.42878473
#   }
# }
# ]
# [label_id: 0
# score: 0.89195544
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40953335
#     ymin: 0.3162145
#     width: 0.2462295
#     height: 0.32830578
#   }
#   relative_keypoints {
#     x: 0.48245844
#     y: 0.4067518
#   }
#   relative_keypoints {
#     x: 0.5947485
#     y: 0.39637262
#   }
#   relative_keypoints {
#     x: 0.5520815
#     y: 0.46938968
#   }
#   relative_keypoints {
#     x: 0.553694
#     y: 0.543948
#   }
#   relative_keypoints {
#     x: 0.41072148
#     y: 0.4561959
#   }
#   relative_keypoints {
#     x: 0.64698094
#     y: 0.42878473
#   }
# }
# ]
# [label_id: 0
# score: 0.89195544
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40953335
#     ymin: 0.3162145
#     width: 0.2462295
#     height: 0.32830578
#   }
#   relative_keypoints {
#     x: 0.48245844
#     y: 0.4067518
#   }
#   relative_keypoints {
#     x: 0.5947485
#     y: 0.39637262
#   }
#   relative_keypoints {
#     x: 0.5520815
#     y: 0.46938968
#   }
#   relative_keypoints {
#     x: 0.553694
#     y: 0.543948
#   }
#   relative_keypoints {
#     x: 0.41072148
#     y: 0.4561959
#   }
#   relative_keypoints {
#     x: 0.64698094
#     y: 0.42878473
#   }
# }
# ]
# [label_id: 0
# score: 0.90164876
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40661296
#     ymin: 0.29381835
#     width: 0.25861982
#     height: 0.34481537
#   }
#   relative_keypoints {
#     x: 0.49103966
#     y: 0.3899755
#   }
#   relative_keypoints {
#     x: 0.60491925
#     y: 0.3824879
#   }
#   relative_keypoints {
#     x: 0.5630187
#     y: 0.46268272
#   }
#   relative_keypoints {
#     x: 0.561418
#     y: 0.53780276
#   }
#   relative_keypoints {
#     x: 0.41159156
#     y: 0.4337744
#   }
#   relative_keypoints {
#     x: 0.6526541
#     y: 0.41382557
#   }
# }
# ]
# [label_id: 0
# score: 0.90164876
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40661296
#     ymin: 0.29381835
#     width: 0.25861982
#     height: 0.34481537
#   }
#   relative_keypoints {
#     x: 0.49103966
#     y: 0.3899755
#   }
#   relative_keypoints {
#     x: 0.60491925
#     y: 0.3824879
#   }
#   relative_keypoints {
#     x: 0.5630187
#     y: 0.46268272
#   }
#   relative_keypoints {
#     x: 0.561418
#     y: 0.53780276
#   }
#   relative_keypoints {
#     x: 0.41159156
#     y: 0.4337744
#   }
#   relative_keypoints {
#     x: 0.6526541
#     y: 0.41382557
#   }
# }
# ]
# [label_id: 0
# score: 0.90164876
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40661296
#     ymin: 0.29381835
#     width: 0.25861982
#     height: 0.34481537
#   }
#   relative_keypoints {
#     x: 0.49103966
#     y: 0.3899755
#   }
#   relative_keypoints {
#     x: 0.60491925
#     y: 0.3824879
#   }
#   relative_keypoints {
#     x: 0.5630187
#     y: 0.46268272
#   }
#   relative_keypoints {
#     x: 0.561418
#     y: 0.53780276
#   }
#   relative_keypoints {
#     x: 0.41159156
#     y: 0.4337744
#   }
#   relative_keypoints {
#     x: 0.6526541
#     y: 0.41382557
#   }
# }
# ]
# [label_id: 0
# score: 0.90164876
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40661296
#     ymin: 0.29381835
#     width: 0.25861982
#     height: 0.34481537
#   }
#   relative_keypoints {
#     x: 0.49103966
#     y: 0.3899755
#   }
#   relative_keypoints {
#     x: 0.60491925
#     y: 0.3824879
#   }
#   relative_keypoints {
#     x: 0.5630187
#     y: 0.46268272
#   }
#   relative_keypoints {
#     x: 0.561418
#     y: 0.53780276
#   }
#   relative_keypoints {
#     x: 0.41159156
#     y: 0.4337744
#   }
#   relative_keypoints {
#     x: 0.6526541
#     y: 0.41382557
#   }
# }
# ]
# [label_id: 0
# score: 0.9110581
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40009663
#     ymin: 0.28761822
#     width: 0.2717794
#     height: 0.36235905
#   }
#   relative_keypoints {
#     x: 0.49831995
#     y: 0.38200158
#   }
#   relative_keypoints {
#     x: 0.61356014
#     y: 0.37956232
#   }
#   relative_keypoints {
#     x: 0.5735066
#     y: 0.45891064
#   }
#   relative_keypoints {
#     x: 0.56709254
#     y: 0.54002327
#   }
#   relative_keypoints {
#     x: 0.40752897
#     y: 0.42897207
#   }
#   relative_keypoints {
#     x: 0.6531917
#     y: 0.4203232
#   }
# }
# ]
# [label_id: 0
# score: 0.9110581
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40009663
#     ymin: 0.28761822
#     width: 0.2717794
#     height: 0.36235905
#   }
#   relative_keypoints {
#     x: 0.49831995
#     y: 0.38200158
#   }
#   relative_keypoints {
#     x: 0.61356014
#     y: 0.37956232
#   }
#   relative_keypoints {
#     x: 0.5735066
#     y: 0.45891064
#   }
#   relative_keypoints {
#     x: 0.56709254
#     y: 0.54002327
#   }
#   relative_keypoints {
#     x: 0.40752897
#     y: 0.42897207
#   }
#   relative_keypoints {
#     x: 0.6531917
#     y: 0.4203232
#   }
# }
# ]
# [label_id: 0
# score: 0.9110581
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40009663
#     ymin: 0.28761822
#     width: 0.2717794
#     height: 0.36235905
#   }
#   relative_keypoints {
#     x: 0.49831995
#     y: 0.38200158
#   }
#   relative_keypoints {
#     x: 0.61356014
#     y: 0.37956232
#   }
#   relative_keypoints {
#     x: 0.5735066
#     y: 0.45891064
#   }
#   relative_keypoints {
#     x: 0.56709254
#     y: 0.54002327
#   }
#   relative_keypoints {
#     x: 0.40752897
#     y: 0.42897207
#   }
#   relative_keypoints {
#     x: 0.6531917
#     y: 0.4203232
#   }
# }
# ]
# [label_id: 0
# score: 0.9110581
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40009663
#     ymin: 0.28761822
#     width: 0.2717794
#     height: 0.36235905
#   }
#   relative_keypoints {
#     x: 0.49831995
#     y: 0.38200158
#   }
#   relative_keypoints {
#     x: 0.61356014
#     y: 0.37956232
#   }
#   relative_keypoints {
#     x: 0.5735066
#     y: 0.45891064
#   }
#   relative_keypoints {
#     x: 0.56709254
#     y: 0.54002327
#   }
#   relative_keypoints {
#     x: 0.40752897
#     y: 0.42897207
#   }
#   relative_keypoints {
#     x: 0.6531917
#     y: 0.4203232
#   }
# }
# ]
# [label_id: 0
# score: 0.89788735
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40141636
#     ymin: 0.3012386
#     width: 0.26402563
#     height: 0.35202235
#   }
#   relative_keypoints {
#     x: 0.49174333
#     y: 0.39006472
#   }
#   relative_keypoints {
#     x: 0.6074767
#     y: 0.38735688
#   }
#   relative_keypoints {
#     x: 0.56573015
#     y: 0.46049637
#   }
#   relative_keypoints {
#     x: 0.56135267
#     y: 0.5432449
#   }
#   relative_keypoints {
#     x: 0.40572017
#     y: 0.44290173
#   }
#   relative_keypoints {
#     x: 0.6513494
#     y: 0.43258005
#   }
# }
# ]
# [label_id: 0
# score: 0.89788735
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40141636
#     ymin: 0.3012386
#     width: 0.26402563
#     height: 0.35202235
#   }
#   relative_keypoints {
#     x: 0.49174333
#     y: 0.39006472
#   }
#   relative_keypoints {
#     x: 0.6074767
#     y: 0.38735688
#   }
#   relative_keypoints {
#     x: 0.56573015
#     y: 0.46049637
#   }
#   relative_keypoints {
#     x: 0.56135267
#     y: 0.5432449
#   }
#   relative_keypoints {
#     x: 0.40572017
#     y: 0.44290173
#   }
#   relative_keypoints {
#     x: 0.6513494
#     y: 0.43258005
#   }
# }
# ]
# [label_id: 0
# score: 0.89788735
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40141636
#     ymin: 0.3012386
#     width: 0.26402563
#     height: 0.35202235
#   }
#   relative_keypoints {
#     x: 0.49174333
#     y: 0.39006472
#   }
#   relative_keypoints {
#     x: 0.6074767
#     y: 0.38735688
#   }
#   relative_keypoints {
#     x: 0.56573015
#     y: 0.46049637
#   }
#   relative_keypoints {
#     x: 0.56135267
#     y: 0.5432449
#   }
#   relative_keypoints {
#     x: 0.40572017
#     y: 0.44290173
#   }
#   relative_keypoints {
#     x: 0.6513494
#     y: 0.43258005
#   }
# }
# ]
# [label_id: 0
# score: 0.89788735
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40141636
#     ymin: 0.3012386
#     width: 0.26402563
#     height: 0.35202235
#   }
#   relative_keypoints {
#     x: 0.49174333
#     y: 0.39006472
#   }
#   relative_keypoints {
#     x: 0.6074767
#     y: 0.38735688
#   }
#   relative_keypoints {
#     x: 0.56573015
#     y: 0.46049637
#   }
#   relative_keypoints {
#     x: 0.56135267
#     y: 0.5432449
#   }
#   relative_keypoints {
#     x: 0.40572017
#     y: 0.44290173
#   }
#   relative_keypoints {
#     x: 0.6513494
#     y: 0.43258005
#   }
# }
# ]
# [label_id: 0
# score: 0.86306477
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39337716
#     ymin: 0.27840108
#     width: 0.28630742
#     height: 0.38171732
#   }
#   relative_keypoints {
#     x: 0.48470765
#     y: 0.3780685
#   }
#   relative_keypoints {
#     x: 0.60840577
#     y: 0.37350887
#   }
#   relative_keypoints {
#     x: 0.55682725
#     y: 0.45877331
#   }
#   relative_keypoints {
#     x: 0.5544688
#     y: 0.54597193
#   }
#   relative_keypoints {
#     x: 0.40374374
#     y: 0.42929196
#   }
#   relative_keypoints {
#     x: 0.66361177
#     y: 0.4168827
#   }
# }
# ]
# [label_id: 0
# score: 0.86306477
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39337716
#     ymin: 0.27840108
#     width: 0.28630742
#     height: 0.38171732
#   }
#   relative_keypoints {
#     x: 0.48470765
#     y: 0.3780685
#   }
#   relative_keypoints {
#     x: 0.60840577
#     y: 0.37350887
#   }
#   relative_keypoints {
#     x: 0.55682725
#     y: 0.45877331
#   }
#   relative_keypoints {
#     x: 0.5544688
#     y: 0.54597193
#   }
#   relative_keypoints {
#     x: 0.40374374
#     y: 0.42929196
#   }
#   relative_keypoints {
#     x: 0.66361177
#     y: 0.4168827
#   }
# }
# ]
# [label_id: 0
# score: 0.86306477
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39337716
#     ymin: 0.27840108
#     width: 0.28630742
#     height: 0.38171732
#   }
#   relative_keypoints {
#     x: 0.48470765
#     y: 0.3780685
#   }
#   relative_keypoints {
#     x: 0.60840577
#     y: 0.37350887
#   }
#   relative_keypoints {
#     x: 0.55682725
#     y: 0.45877331
#   }
#   relative_keypoints {
#     x: 0.5544688
#     y: 0.54597193
#   }
#   relative_keypoints {
#     x: 0.40374374
#     y: 0.42929196
#   }
#   relative_keypoints {
#     x: 0.66361177
#     y: 0.4168827
#   }
# }
# ]
# [label_id: 0
# score: 0.86306477
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39337716
#     ymin: 0.27840108
#     width: 0.28630742
#     height: 0.38171732
#   }
#   relative_keypoints {
#     x: 0.48470765
#     y: 0.3780685
#   }
#   relative_keypoints {
#     x: 0.60840577
#     y: 0.37350887
#   }
#   relative_keypoints {
#     x: 0.55682725
#     y: 0.45877331
#   }
#   relative_keypoints {
#     x: 0.5544688
#     y: 0.54597193
#   }
#   relative_keypoints {
#     x: 0.40374374
#     y: 0.42929196
#   }
#   relative_keypoints {
#     x: 0.66361177
#     y: 0.4168827
#   }
# }
# ]
# [label_id: 0
# score: 0.85455084
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39867908
#     ymin: 0.28457838
#     width: 0.27363276
#     height: 0.364828
#   }
#   relative_keypoints {
#     x: 0.50295013
#     y: 0.39057755
#   }
#   relative_keypoints {
#     x: 0.616201
#     y: 0.39621955
#   }
#   relative_keypoints {
#     x: 0.57545865
#     y: 0.48342746
#   }
#   relative_keypoints {
#     x: 0.5639972
#     y: 0.55568427
#   }
#   relative_keypoints {
#     x: 0.40650752
#     y: 0.40784478
#   }
#   relative_keypoints {
#     x: 0.64866096
#     y: 0.4174202
#   }
# }
# ]
# [label_id: 0
# score: 0.85455084
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39867908
#     ymin: 0.28457838
#     width: 0.27363276
#     height: 0.364828
#   }
#   relative_keypoints {
#     x: 0.50295013
#     y: 0.39057755
#   }
#   relative_keypoints {
#     x: 0.616201
#     y: 0.39621955
#   }
#   relative_keypoints {
#     x: 0.57545865
#     y: 0.48342746
#   }
#   relative_keypoints {
#     x: 0.5639972
#     y: 0.55568427
#   }
#   relative_keypoints {
#     x: 0.40650752
#     y: 0.40784478
#   }
#   relative_keypoints {
#     x: 0.64866096
#     y: 0.4174202
#   }
# }
# ]
# [label_id: 0
# score: 0.85455084
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39867908
#     ymin: 0.28457838
#     width: 0.27363276
#     height: 0.364828
#   }
#   relative_keypoints {
#     x: 0.50295013
#     y: 0.39057755
#   }
#   relative_keypoints {
#     x: 0.616201
#     y: 0.39621955
#   }
#   relative_keypoints {
#     x: 0.57545865
#     y: 0.48342746
#   }
#   relative_keypoints {
#     x: 0.5639972
#     y: 0.55568427
#   }
#   relative_keypoints {
#     x: 0.40650752
#     y: 0.40784478
#   }
#   relative_keypoints {
#     x: 0.64866096
#     y: 0.4174202
#   }
# }
# ]
# [label_id: 0
# score: 0.85455084
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39867908
#     ymin: 0.28457838
#     width: 0.27363276
#     height: 0.364828
#   }
#   relative_keypoints {
#     x: 0.50295013
#     y: 0.39057755
#   }
#   relative_keypoints {
#     x: 0.616201
#     y: 0.39621955
#   }
#   relative_keypoints {
#     x: 0.57545865
#     y: 0.48342746
#   }
#   relative_keypoints {
#     x: 0.5639972
#     y: 0.55568427
#   }
#   relative_keypoints {
#     x: 0.40650752
#     y: 0.40784478
#   }
#   relative_keypoints {
#     x: 0.64866096
#     y: 0.4174202
#   }
# }
# ]
# [label_id: 0
# score: 0.86184794
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40622225
#     ymin: 0.29984623
#     width: 0.25493434
#     height: 0.33991182
#   }
#   relative_keypoints {
#     x: 0.5033647
#     y: 0.38797575
#   }
#   relative_keypoints {
#     x: 0.6143051
#     y: 0.39800543
#   }
#   relative_keypoints {
#     x: 0.57575864
#     y: 0.4653895
#   }
#   relative_keypoints {
#     x: 0.5641803
#     y: 0.53967994
#   }
#   relative_keypoints {
#     x: 0.40636545
#     y: 0.4192313
#   }
#   relative_keypoints {
#     x: 0.6424511
#     y: 0.43368912
#   }
# }
# ]
# [label_id: 0
# score: 0.86184794
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40622225
#     ymin: 0.29984623
#     width: 0.25493434
#     height: 0.33991182
#   }
#   relative_keypoints {
#     x: 0.5033647
#     y: 0.38797575
#   }
#   relative_keypoints {
#     x: 0.6143051
#     y: 0.39800543
#   }
#   relative_keypoints {
#     x: 0.57575864
#     y: 0.4653895
#   }
#   relative_keypoints {
#     x: 0.5641803
#     y: 0.53967994
#   }
#   relative_keypoints {
#     x: 0.40636545
#     y: 0.4192313
#   }
#   relative_keypoints {
#     x: 0.6424511
#     y: 0.43368912
#   }
# }
# ]
# [label_id: 0
# score: 0.86184794
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40622225
#     ymin: 0.29984623
#     width: 0.25493434
#     height: 0.33991182
#   }
#   relative_keypoints {
#     x: 0.5033647
#     y: 0.38797575
#   }
#   relative_keypoints {
#     x: 0.6143051
#     y: 0.39800543
#   }
#   relative_keypoints {
#     x: 0.57575864
#     y: 0.4653895
#   }
#   relative_keypoints {
#     x: 0.5641803
#     y: 0.53967994
#   }
#   relative_keypoints {
#     x: 0.40636545
#     y: 0.4192313
#   }
#   relative_keypoints {
#     x: 0.6424511
#     y: 0.43368912
#   }
# }
# ]
# [label_id: 0
# score: 0.86184794
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40622225
#     ymin: 0.29984623
#     width: 0.25493434
#     height: 0.33991182
#   }
#   relative_keypoints {
#     x: 0.5033647
#     y: 0.38797575
#   }
#   relative_keypoints {
#     x: 0.6143051
#     y: 0.39800543
#   }
#   relative_keypoints {
#     x: 0.57575864
#     y: 0.4653895
#   }
#   relative_keypoints {
#     x: 0.5641803
#     y: 0.53967994
#   }
#   relative_keypoints {
#     x: 0.40636545
#     y: 0.4192313
#   }
#   relative_keypoints {
#     x: 0.6424511
#     y: 0.43368912
#   }
# }
# ]
# [label_id: 0
# score: 0.83951277
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.404055
#     ymin: 0.283392
#     width: 0.2706831
#     height: 0.36089718
#   }
#   relative_keypoints {
#     x: 0.50186765
#     y: 0.38612866
#   }
#   relative_keypoints {
#     x: 0.61915404
#     y: 0.38241678
#   }
#   relative_keypoints {
#     x: 0.5783815
#     y: 0.46556103
#   }
#   relative_keypoints {
#     x: 0.5714872
#     y: 0.5423872
#   }
#   relative_keypoints {
#     x: 0.40895203
#     y: 0.42155576
#   }
#   relative_keypoints {
#     x: 0.65747625
#     y: 0.41110164
#   }
# }
# ]
# [label_id: 0
# score: 0.83951277
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.404055
#     ymin: 0.283392
#     width: 0.2706831
#     height: 0.36089718
#   }
#   relative_keypoints {
#     x: 0.50186765
#     y: 0.38612866
#   }
#   relative_keypoints {
#     x: 0.61915404
#     y: 0.38241678
#   }
#   relative_keypoints {
#     x: 0.5783815
#     y: 0.46556103
#   }
#   relative_keypoints {
#     x: 0.5714872
#     y: 0.5423872
#   }
#   relative_keypoints {
#     x: 0.40895203
#     y: 0.42155576
#   }
#   relative_keypoints {
#     x: 0.65747625
#     y: 0.41110164
#   }
# }
# ]
# [label_id: 0
# score: 0.83951277
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.404055
#     ymin: 0.283392
#     width: 0.2706831
#     height: 0.36089718
#   }
#   relative_keypoints {
#     x: 0.50186765
#     y: 0.38612866
#   }
#   relative_keypoints {
#     x: 0.61915404
#     y: 0.38241678
#   }
#   relative_keypoints {
#     x: 0.5783815
#     y: 0.46556103
#   }
#   relative_keypoints {
#     x: 0.5714872
#     y: 0.5423872
#   }
#   relative_keypoints {
#     x: 0.40895203
#     y: 0.42155576
#   }
#   relative_keypoints {
#     x: 0.65747625
#     y: 0.41110164
#   }
# }
# ]
# [label_id: 0
# score: 0.83951277
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.404055
#     ymin: 0.283392
#     width: 0.2706831
#     height: 0.36089718
#   }
#   relative_keypoints {
#     x: 0.50186765
#     y: 0.38612866
#   }
#   relative_keypoints {
#     x: 0.61915404
#     y: 0.38241678
#   }
#   relative_keypoints {
#     x: 0.5783815
#     y: 0.46556103
#   }
#   relative_keypoints {
#     x: 0.5714872
#     y: 0.5423872
#   }
#   relative_keypoints {
#     x: 0.40895203
#     y: 0.42155576
#   }
#   relative_keypoints {
#     x: 0.65747625
#     y: 0.41110164
#   }
# }
# ]
# [label_id: 0
# score: 0.8051648
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40334448
#     ymin: 0.28351647
#     width: 0.2664005
#     height: 0.35518783
#   }
#   relative_keypoints {
#     x: 0.5069765
#     y: 0.3879791
#   }
#   relative_keypoints {
#     x: 0.6179245
#     y: 0.39151227
#   }
#   relative_keypoints {
#     x: 0.57957023
#     y: 0.47324783
#   }
#   relative_keypoints {
#     x: 0.5678363
#     y: 0.5445833
#   }
#   relative_keypoints {
#     x: 0.41048124
#     y: 0.40581506
#   }
#   relative_keypoints {
#     x: 0.6479872
#     y: 0.4122141
#   }
# }
# ]
# [label_id: 0
# score: 0.8051648
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40334448
#     ymin: 0.28351647
#     width: 0.2664005
#     height: 0.35518783
#   }
#   relative_keypoints {
#     x: 0.5069765
#     y: 0.3879791
#   }
#   relative_keypoints {
#     x: 0.6179245
#     y: 0.39151227
#   }
#   relative_keypoints {
#     x: 0.57957023
#     y: 0.47324783
#   }
#   relative_keypoints {
#     x: 0.5678363
#     y: 0.5445833
#   }
#   relative_keypoints {
#     x: 0.41048124
#     y: 0.40581506
#   }
#   relative_keypoints {
#     x: 0.6479872
#     y: 0.4122141
#   }
# }
# ]
# [label_id: 0
# score: 0.8051648
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40334448
#     ymin: 0.28351647
#     width: 0.2664005
#     height: 0.35518783
#   }
#   relative_keypoints {
#     x: 0.5069765
#     y: 0.3879791
#   }
#   relative_keypoints {
#     x: 0.6179245
#     y: 0.39151227
#   }
#   relative_keypoints {
#     x: 0.57957023
#     y: 0.47324783
#   }
#   relative_keypoints {
#     x: 0.5678363
#     y: 0.5445833
#   }
#   relative_keypoints {
#     x: 0.41048124
#     y: 0.40581506
#   }
#   relative_keypoints {
#     x: 0.6479872
#     y: 0.4122141
#   }
# }
# ]
# [label_id: 0
# score: 0.8051648
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40334448
#     ymin: 0.28351647
#     width: 0.2664005
#     height: 0.35518783
#   }
#   relative_keypoints {
#     x: 0.5069765
#     y: 0.3879791
#   }
#   relative_keypoints {
#     x: 0.6179245
#     y: 0.39151227
#   }
#   relative_keypoints {
#     x: 0.57957023
#     y: 0.47324783
#   }
#   relative_keypoints {
#     x: 0.5678363
#     y: 0.5445833
#   }
#   relative_keypoints {
#     x: 0.41048124
#     y: 0.40581506
#   }
#   relative_keypoints {
#     x: 0.6479872
#     y: 0.4122141
#   }
# }
# ]
# [label_id: 0
# score: 0.7636937
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39889917
#     ymin: 0.27911168
#     width: 0.27208725
#     height: 0.36276978
#   }
#   relative_keypoints {
#     x: 0.49795154
#     y: 0.3810693
#   }
#   relative_keypoints {
#     x: 0.614591
#     y: 0.38625103
#   }
#   relative_keypoints {
#     x: 0.5695809
#     y: 0.46639043
#   }
#   relative_keypoints {
#     x: 0.55944276
#     y: 0.54338145
#   }
#   relative_keypoints {
#     x: 0.40510288
#     y: 0.4076619
#   }
#   relative_keypoints {
#     x: 0.6521998
#     y: 0.41633743
#   }
# }
# ]
# [label_id: 0
# score: 0.7636937
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39889917
#     ymin: 0.27911168
#     width: 0.27208725
#     height: 0.36276978
#   }
#   relative_keypoints {
#     x: 0.49795154
#     y: 0.3810693
#   }
#   relative_keypoints {
#     x: 0.614591
#     y: 0.38625103
#   }
#   relative_keypoints {
#     x: 0.5695809
#     y: 0.46639043
#   }
#   relative_keypoints {
#     x: 0.55944276
#     y: 0.54338145
#   }
#   relative_keypoints {
#     x: 0.40510288
#     y: 0.4076619
#   }
#   relative_keypoints {
#     x: 0.6521998
#     y: 0.41633743
#   }
# }
# ]
# [label_id: 0
# score: 0.7636937
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39889917
#     ymin: 0.27911168
#     width: 0.27208725
#     height: 0.36276978
#   }
#   relative_keypoints {
#     x: 0.49795154
#     y: 0.3810693
#   }
#   relative_keypoints {
#     x: 0.614591
#     y: 0.38625103
#   }
#   relative_keypoints {
#     x: 0.5695809
#     y: 0.46639043
#   }
#   relative_keypoints {
#     x: 0.55944276
#     y: 0.54338145
#   }
#   relative_keypoints {
#     x: 0.40510288
#     y: 0.4076619
#   }
#   relative_keypoints {
#     x: 0.6521998
#     y: 0.41633743
#   }
# }
# ]
# [label_id: 0
# score: 0.7636937
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39889917
#     ymin: 0.27911168
#     width: 0.27208725
#     height: 0.36276978
#   }
#   relative_keypoints {
#     x: 0.49795154
#     y: 0.3810693
#   }
#   relative_keypoints {
#     x: 0.614591
#     y: 0.38625103
#   }
#   relative_keypoints {
#     x: 0.5695809
#     y: 0.46639043
#   }
#   relative_keypoints {
#     x: 0.55944276
#     y: 0.54338145
#   }
#   relative_keypoints {
#     x: 0.40510288
#     y: 0.4076619
#   }
#   relative_keypoints {
#     x: 0.6521998
#     y: 0.41633743
#   }
# }
# ]
# [label_id: 0
# score: 0.7777674
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40192437
#     ymin: 0.2784751
#     width: 0.27396262
#     height: 0.36526895
#   }
#   relative_keypoints {
#     x: 0.49046016
#     y: 0.37160426
#   }
#   relative_keypoints {
#     x: 0.6085607
#     y: 0.37765223
#   }
#   relative_keypoints {
#     x: 0.5545271
#     y: 0.45118183
#   }
#   relative_keypoints {
#     x: 0.5476693
#     y: 0.53513813
#   }
#   relative_keypoints {
#     x: 0.41067266
#     y: 0.4099118
#   }
#   relative_keypoints {
#     x: 0.6613338
#     y: 0.42127186
#   }
# }
# ]
# [label_id: 0
# score: 0.7777674
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40192437
#     ymin: 0.2784751
#     width: 0.27396262
#     height: 0.36526895
#   }
#   relative_keypoints {
#     x: 0.49046016
#     y: 0.37160426
#   }
#   relative_keypoints {
#     x: 0.6085607
#     y: 0.37765223
#   }
#   relative_keypoints {
#     x: 0.5545271
#     y: 0.45118183
#   }
#   relative_keypoints {
#     x: 0.5476693
#     y: 0.53513813
#   }
#   relative_keypoints {
#     x: 0.41067266
#     y: 0.4099118
#   }
#   relative_keypoints {
#     x: 0.6613338
#     y: 0.42127186
#   }
# }
# ]
# [label_id: 0
# score: 0.7777674
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40192437
#     ymin: 0.2784751
#     width: 0.27396262
#     height: 0.36526895
#   }
#   relative_keypoints {
#     x: 0.49046016
#     y: 0.37160426
#   }
#   relative_keypoints {
#     x: 0.6085607
#     y: 0.37765223
#   }
#   relative_keypoints {
#     x: 0.5545271
#     y: 0.45118183
#   }
#   relative_keypoints {
#     x: 0.5476693
#     y: 0.53513813
#   }
#   relative_keypoints {
#     x: 0.41067266
#     y: 0.4099118
#   }
#   relative_keypoints {
#     x: 0.6613338
#     y: 0.42127186
#   }
# }
# ]
# [label_id: 0
# score: 0.7777674
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40192437
#     ymin: 0.2784751
#     width: 0.27396262
#     height: 0.36526895
#   }
#   relative_keypoints {
#     x: 0.49046016
#     y: 0.37160426
#   }
#   relative_keypoints {
#     x: 0.6085607
#     y: 0.37765223
#   }
#   relative_keypoints {
#     x: 0.5545271
#     y: 0.45118183
#   }
#   relative_keypoints {
#     x: 0.5476693
#     y: 0.53513813
#   }
#   relative_keypoints {
#     x: 0.41067266
#     y: 0.4099118
#   }
#   relative_keypoints {
#     x: 0.6613338
#     y: 0.42127186
#   }
# }
# ]
# [label_id: 0
# score: 0.78086096
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4180947
#     ymin: 0.28752613
#     width: 0.26134628
#     height: 0.34844965
#   }
#   relative_keypoints {
#     x: 0.50760406
#     y: 0.36870307
#   }
#   relative_keypoints {
#     x: 0.6209548
#     y: 0.3850246
#   }
#   relative_keypoints {
#     x: 0.56697434
#     y: 0.44506818
#   }
#   relative_keypoints {
#     x: 0.55536646
#     y: 0.52732784
#   }
#   relative_keypoints {
#     x: 0.4237892
#     y: 0.4054706
#   }
#   relative_keypoints {
#     x: 0.6659546
#     y: 0.4377374
#   }
# }
# ]
# [label_id: 0
# score: 0.78086096
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4180947
#     ymin: 0.28752613
#     width: 0.26134628
#     height: 0.34844965
#   }
#   relative_keypoints {
#     x: 0.50760406
#     y: 0.36870307
#   }
#   relative_keypoints {
#     x: 0.6209548
#     y: 0.3850246
#   }
#   relative_keypoints {
#     x: 0.56697434
#     y: 0.44506818
#   }
#   relative_keypoints {
#     x: 0.55536646
#     y: 0.52732784
#   }
#   relative_keypoints {
#     x: 0.4237892
#     y: 0.4054706
#   }
#   relative_keypoints {
#     x: 0.6659546
#     y: 0.4377374
#   }
# }
# ]
# [label_id: 0
# score: 0.78086096
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4180947
#     ymin: 0.28752613
#     width: 0.26134628
#     height: 0.34844965
#   }
#   relative_keypoints {
#     x: 0.50760406
#     y: 0.36870307
#   }
#   relative_keypoints {
#     x: 0.6209548
#     y: 0.3850246
#   }
#   relative_keypoints {
#     x: 0.56697434
#     y: 0.44506818
#   }
#   relative_keypoints {
#     x: 0.55536646
#     y: 0.52732784
#   }
#   relative_keypoints {
#     x: 0.4237892
#     y: 0.4054706
#   }
#   relative_keypoints {
#     x: 0.6659546
#     y: 0.4377374
#   }
# }
# ]
# [label_id: 0
# score: 0.78086096
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4180947
#     ymin: 0.28752613
#     width: 0.26134628
#     height: 0.34844965
#   }
#   relative_keypoints {
#     x: 0.50760406
#     y: 0.36870307
#   }
#   relative_keypoints {
#     x: 0.6209548
#     y: 0.3850246
#   }
#   relative_keypoints {
#     x: 0.56697434
#     y: 0.44506818
#   }
#   relative_keypoints {
#     x: 0.55536646
#     y: 0.52732784
#   }
#   relative_keypoints {
#     x: 0.4237892
#     y: 0.4054706
#   }
#   relative_keypoints {
#     x: 0.6659546
#     y: 0.4377374
#   }
# }
# ]
# [label_id: 0
# score: 0.7974704
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41117808
#     ymin: 0.29319572
#     width: 0.2574177
#     height: 0.34322304
#   }
#   relative_keypoints {
#     x: 0.48781067
#     y: 0.38189834
#   }
#   relative_keypoints {
#     x: 0.60697573
#     y: 0.38184994
#   }
#   relative_keypoints {
#     x: 0.5558936
#     y: 0.45092803
#   }
#   relative_keypoints {
#     x: 0.5533217
#     y: 0.5317414
#   }
#   relative_keypoints {
#     x: 0.41087204
#     y: 0.42652118
#   }
#   relative_keypoints {
#     x: 0.6605083
#     y: 0.42018145
#   }
# }
# ]
# [label_id: 0
# score: 0.7974704
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41117808
#     ymin: 0.29319572
#     width: 0.2574177
#     height: 0.34322304
#   }
#   relative_keypoints {
#     x: 0.48781067
#     y: 0.38189834
#   }
#   relative_keypoints {
#     x: 0.60697573
#     y: 0.38184994
#   }
#   relative_keypoints {
#     x: 0.5558936
#     y: 0.45092803
#   }
#   relative_keypoints {
#     x: 0.5533217
#     y: 0.5317414
#   }
#   relative_keypoints {
#     x: 0.41087204
#     y: 0.42652118
#   }
#   relative_keypoints {
#     x: 0.6605083
#     y: 0.42018145
#   }
# }
# ]
# [label_id: 0
# score: 0.7974704
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41117808
#     ymin: 0.29319572
#     width: 0.2574177
#     height: 0.34322304
#   }
#   relative_keypoints {
#     x: 0.48781067
#     y: 0.38189834
#   }
#   relative_keypoints {
#     x: 0.60697573
#     y: 0.38184994
#   }
#   relative_keypoints {
#     x: 0.5558936
#     y: 0.45092803
#   }
#   relative_keypoints {
#     x: 0.5533217
#     y: 0.5317414
#   }
#   relative_keypoints {
#     x: 0.41087204
#     y: 0.42652118
#   }
#   relative_keypoints {
#     x: 0.6605083
#     y: 0.42018145
#   }
# }
# ]
# [label_id: 0
# score: 0.7974704
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41117808
#     ymin: 0.29319572
#     width: 0.2574177
#     height: 0.34322304
#   }
#   relative_keypoints {
#     x: 0.48781067
#     y: 0.38189834
#   }
#   relative_keypoints {
#     x: 0.60697573
#     y: 0.38184994
#   }
#   relative_keypoints {
#     x: 0.5558936
#     y: 0.45092803
#   }
#   relative_keypoints {
#     x: 0.5533217
#     y: 0.5317414
#   }
#   relative_keypoints {
#     x: 0.41087204
#     y: 0.42652118
#   }
#   relative_keypoints {
#     x: 0.6605083
#     y: 0.42018145
#   }
# }
# ]
# [label_id: 0
# score: 0.8286633
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41284505
#     ymin: 0.2853431
#     width: 0.2622865
#     height: 0.3497032
#   }
#   relative_keypoints {
#     x: 0.50594574
#     y: 0.3715158
#   }
#   relative_keypoints {
#     x: 0.62025523
#     y: 0.39234465
#   }
#   relative_keypoints {
#     x: 0.56608385
#     y: 0.45806223
#   }
#   relative_keypoints {
#     x: 0.5520297
#     y: 0.534437
#   }
#   relative_keypoints {
#     x: 0.418341
#     y: 0.39580297
#   }
#   relative_keypoints {
#     x: 0.66025925
#     y: 0.43717736
#   }
# }
# ]
# [label_id: 0
# score: 0.8286633
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41284505
#     ymin: 0.2853431
#     width: 0.2622865
#     height: 0.3497032
#   }
#   relative_keypoints {
#     x: 0.50594574
#     y: 0.3715158
#   }
#   relative_keypoints {
#     x: 0.62025523
#     y: 0.39234465
#   }
#   relative_keypoints {
#     x: 0.56608385
#     y: 0.45806223
#   }
#   relative_keypoints {
#     x: 0.5520297
#     y: 0.534437
#   }
#   relative_keypoints {
#     x: 0.418341
#     y: 0.39580297
#   }
#   relative_keypoints {
#     x: 0.66025925
#     y: 0.43717736
#   }
# }
# ]
# [label_id: 0
# score: 0.8286633
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41284505
#     ymin: 0.2853431
#     width: 0.2622865
#     height: 0.3497032
#   }
#   relative_keypoints {
#     x: 0.50594574
#     y: 0.3715158
#   }
#   relative_keypoints {
#     x: 0.62025523
#     y: 0.39234465
#   }
#   relative_keypoints {
#     x: 0.56608385
#     y: 0.45806223
#   }
#   relative_keypoints {
#     x: 0.5520297
#     y: 0.534437
#   }
#   relative_keypoints {
#     x: 0.418341
#     y: 0.39580297
#   }
#   relative_keypoints {
#     x: 0.66025925
#     y: 0.43717736
#   }
# }
# ]
# [label_id: 0
# score: 0.8286633
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41284505
#     ymin: 0.2853431
#     width: 0.2622865
#     height: 0.3497032
#   }
#   relative_keypoints {
#     x: 0.50594574
#     y: 0.3715158
#   }
#   relative_keypoints {
#     x: 0.62025523
#     y: 0.39234465
#   }
#   relative_keypoints {
#     x: 0.56608385
#     y: 0.45806223
#   }
#   relative_keypoints {
#     x: 0.5520297
#     y: 0.534437
#   }
#   relative_keypoints {
#     x: 0.418341
#     y: 0.39580297
#   }
#   relative_keypoints {
#     x: 0.66025925
#     y: 0.43717736
#   }
# }
# ]
# [label_id: 0
# score: 0.8472892
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41340137
#     ymin: 0.29188257
#     width: 0.25739068
#     height: 0.34318697
#   }
#   relative_keypoints {
#     x: 0.515011
#     y: 0.3782224
#   }
#   relative_keypoints {
#     x: 0.62441564
#     y: 0.39612305
#   }
#   relative_keypoints {
#     x: 0.58156794
#     y: 0.46000487
#   }
#   relative_keypoints {
#     x: 0.56490797
#     y: 0.53442353
#   }
#   relative_keypoints {
#     x: 0.41511166
#     y: 0.40238553
#   }
#   relative_keypoints {
#     x: 0.64990467
#     y: 0.43572342
#   }
# }
# ]
# [label_id: 0
# score: 0.8472892
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41340137
#     ymin: 0.29188257
#     width: 0.25739068
#     height: 0.34318697
#   }
#   relative_keypoints {
#     x: 0.515011
#     y: 0.3782224
#   }
#   relative_keypoints {
#     x: 0.62441564
#     y: 0.39612305
#   }
#   relative_keypoints {
#     x: 0.58156794
#     y: 0.46000487
#   }
#   relative_keypoints {
#     x: 0.56490797
#     y: 0.53442353
#   }
#   relative_keypoints {
#     x: 0.41511166
#     y: 0.40238553
#   }
#   relative_keypoints {
#     x: 0.64990467
#     y: 0.43572342
#   }
# }
# ]
# [label_id: 0
# score: 0.8472892
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41340137
#     ymin: 0.29188257
#     width: 0.25739068
#     height: 0.34318697
#   }
#   relative_keypoints {
#     x: 0.515011
#     y: 0.3782224
#   }
#   relative_keypoints {
#     x: 0.62441564
#     y: 0.39612305
#   }
#   relative_keypoints {
#     x: 0.58156794
#     y: 0.46000487
#   }
#   relative_keypoints {
#     x: 0.56490797
#     y: 0.53442353
#   }
#   relative_keypoints {
#     x: 0.41511166
#     y: 0.40238553
#   }
#   relative_keypoints {
#     x: 0.64990467
#     y: 0.43572342
#   }
# }
# ]
# [label_id: 0
# score: 0.8472892
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41340137
#     ymin: 0.29188257
#     width: 0.25739068
#     height: 0.34318697
#   }
#   relative_keypoints {
#     x: 0.515011
#     y: 0.3782224
#   }
#   relative_keypoints {
#     x: 0.62441564
#     y: 0.39612305
#   }
#   relative_keypoints {
#     x: 0.58156794
#     y: 0.46000487
#   }
#   relative_keypoints {
#     x: 0.56490797
#     y: 0.53442353
#   }
#   relative_keypoints {
#     x: 0.41511166
#     y: 0.40238553
#   }
#   relative_keypoints {
#     x: 0.64990467
#     y: 0.43572342
#   }
# }
# ]
# ...
#     y: 0.39773345
#   }
# }
# ]
# [label_id: 0
# score: 0.9448432
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4736797
#     ymin: 0.32649457
#     width: 0.18433228
#     height: 0.24577647
#   }
#   relative_keypoints {
#     x: 0.51682645
#     y: 0.4022075
#   }
#   relative_keypoints {
#     x: 0.60009724
#     y: 0.38116688
#   }
#   relative_keypoints {
#     x: 0.5637841
#     y: 0.4457044
#   }
#   relative_keypoints {
#     x: 0.57272285
#     y: 0.4979834
#   }
#   relative_keypoints {
#     x: 0.4778519
#     y: 0.44210303
#   }
#   relative_keypoints {
#     x: 0.6538559
#     y: 0.39773345
#   }
# }
# ]
# [label_id: 0
# score: 0.9306014
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48027766
#     ymin: 0.31416112
#     width: 0.190005
#     height: 0.25334
#   }
#   relative_keypoints {
#     x: 0.52224505
#     y: 0.39553142
#   }
#   relative_keypoints {
#     x: 0.60556215
#     y: 0.3704669
#   }
#   relative_keypoints {
#     x: 0.56833
#     y: 0.43938357
#   }
#   relative_keypoints {
#     x: 0.5797526
#     y: 0.49293643
#   }
#   relative_keypoints {
#     x: 0.4875226
#     y: 0.43740803
#   }
#   relative_keypoints {
#     x: 0.6646404
#     y: 0.3845961
#   }
# }
# ]
# [label_id: 0
# score: 0.9306014
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48027766
#     ymin: 0.31416112
#     width: 0.190005
#     height: 0.25334
#   }
#   relative_keypoints {
#     x: 0.52224505
#     y: 0.39553142
#   }
#   relative_keypoints {
#     x: 0.60556215
#     y: 0.3704669
#   }
#   relative_keypoints {
#     x: 0.56833
#     y: 0.43938357
#   }
#   relative_keypoints {
#     x: 0.5797526
#     y: 0.49293643
#   }
#   relative_keypoints {
#     x: 0.4875226
#     y: 0.43740803
#   }
#   relative_keypoints {
#     x: 0.6646404
#     y: 0.3845961
#   }
# }
# ]
# [label_id: 0
# score: 0.9306014
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48027766
#     ymin: 0.31416112
#     width: 0.190005
#     height: 0.25334
#   }
#   relative_keypoints {
#     x: 0.52224505
#     y: 0.39553142
#   }
#   relative_keypoints {
#     x: 0.60556215
#     y: 0.3704669
#   }
#   relative_keypoints {
#     x: 0.56833
#     y: 0.43938357
#   }
#   relative_keypoints {
#     x: 0.5797526
#     y: 0.49293643
#   }
#   relative_keypoints {
#     x: 0.4875226
#     y: 0.43740803
#   }
#   relative_keypoints {
#     x: 0.6646404
#     y: 0.3845961
#   }
# }
# ]
# [label_id: 0
# score: 0.9306014
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48027766
#     ymin: 0.31416112
#     width: 0.190005
#     height: 0.25334
#   }
#   relative_keypoints {
#     x: 0.52224505
#     y: 0.39553142
#   }
#   relative_keypoints {
#     x: 0.60556215
#     y: 0.3704669
#   }
#   relative_keypoints {
#     x: 0.56833
#     y: 0.43938357
#   }
#   relative_keypoints {
#     x: 0.5797526
#     y: 0.49293643
#   }
#   relative_keypoints {
#     x: 0.4875226
#     y: 0.43740803
#   }
#   relative_keypoints {
#     x: 0.6646404
#     y: 0.3845961
#   }
# }
# ]
# [label_id: 0
# score: 0.955529
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48202023
#     ymin: 0.3294996
#     width: 0.18114588
#     height: 0.24152786
#   }
#   relative_keypoints {
#     x: 0.5276983
#     y: 0.39988154
#   }
#   relative_keypoints {
#     x: 0.60829175
#     y: 0.38024575
#   }
#   relative_keypoints {
#     x: 0.57427484
#     y: 0.44044048
#   }
#   relative_keypoints {
#     x: 0.5814241
#     y: 0.49480957
#   }
#   relative_keypoints {
#     x: 0.48621348
#     y: 0.44336295
#   }
#   relative_keypoints {
#     x: 0.6576644
#     y: 0.4023102
#   }
# }
# ]
# [label_id: 0
# score: 0.955529
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48202023
#     ymin: 0.3294996
#     width: 0.18114588
#     height: 0.24152786
#   }
#   relative_keypoints {
#     x: 0.5276983
#     y: 0.39988154
#   }
#   relative_keypoints {
#     x: 0.60829175
#     y: 0.38024575
#   }
#   relative_keypoints {
#     x: 0.57427484
#     y: 0.44044048
#   }
#   relative_keypoints {
#     x: 0.5814241
#     y: 0.49480957
#   }
#   relative_keypoints {
#     x: 0.48621348
#     y: 0.44336295
#   }
#   relative_keypoints {
#     x: 0.6576644
#     y: 0.4023102
#   }
# }
# ]
# [label_id: 0
# score: 0.955529
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48202023
#     ymin: 0.3294996
#     width: 0.18114588
#     height: 0.24152786
#   }
#   relative_keypoints {
#     x: 0.5276983
#     y: 0.39988154
#   }
#   relative_keypoints {
#     x: 0.60829175
#     y: 0.38024575
#   }
#   relative_keypoints {
#     x: 0.57427484
#     y: 0.44044048
#   }
#   relative_keypoints {
#     x: 0.5814241
#     y: 0.49480957
#   }
#   relative_keypoints {
#     x: 0.48621348
#     y: 0.44336295
#   }
#   relative_keypoints {
#     x: 0.6576644
#     y: 0.4023102
#   }
# }
# ]
# [label_id: 0
# score: 0.955529
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48202023
#     ymin: 0.3294996
#     width: 0.18114588
#     height: 0.24152786
#   }
#   relative_keypoints {
#     x: 0.5276983
#     y: 0.39988154
#   }
#   relative_keypoints {
#     x: 0.60829175
#     y: 0.38024575
#   }
#   relative_keypoints {
#     x: 0.57427484
#     y: 0.44044048
#   }
#   relative_keypoints {
#     x: 0.5814241
#     y: 0.49480957
#   }
#   relative_keypoints {
#     x: 0.48621348
#     y: 0.44336295
#   }
#   relative_keypoints {
#     x: 0.6576644
#     y: 0.4023102
#   }
# }
# ]
# [label_id: 0
# score: 0.94769484
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48354012
#     ymin: 0.33577722
#     width: 0.17828202
#     height: 0.2377091
#   }
#   relative_keypoints {
#     x: 0.53061813
#     y: 0.4092452
#   }
#   relative_keypoints {
#     x: 0.60897833
#     y: 0.38115984
#   }
#   relative_keypoints {
#     x: 0.58172035
#     y: 0.44218057
#   }
#   relative_keypoints {
#     x: 0.59073126
#     y: 0.49647188
#   }
#   relative_keypoints {
#     x: 0.48753616
#     y: 0.4596361
#   }
#   relative_keypoints {
#     x: 0.6554595
#     y: 0.40034527
#   }
# }
# ]
# [label_id: 0
# score: 0.94769484
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48354012
#     ymin: 0.33577722
#     width: 0.17828202
#     height: 0.2377091
#   }
#   relative_keypoints {
#     x: 0.53061813
#     y: 0.4092452
#   }
#   relative_keypoints {
#     x: 0.60897833
#     y: 0.38115984
#   }
#   relative_keypoints {
#     x: 0.58172035
#     y: 0.44218057
#   }
#   relative_keypoints {
#     x: 0.59073126
#     y: 0.49647188
#   }
#   relative_keypoints {
#     x: 0.48753616
#     y: 0.4596361
#   }
#   relative_keypoints {
#     x: 0.6554595
#     y: 0.40034527
#   }
# }
# ]
# [label_id: 0
# score: 0.94769484
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48354012
#     ymin: 0.33577722
#     width: 0.17828202
#     height: 0.2377091
#   }
#   relative_keypoints {
#     x: 0.53061813
#     y: 0.4092452
#   }
#   relative_keypoints {
#     x: 0.60897833
#     y: 0.38115984
#   }
#   relative_keypoints {
#     x: 0.58172035
#     y: 0.44218057
#   }
#   relative_keypoints {
#     x: 0.59073126
#     y: 0.49647188
#   }
#   relative_keypoints {
#     x: 0.48753616
#     y: 0.4596361
#   }
#   relative_keypoints {
#     x: 0.6554595
#     y: 0.40034527
#   }
# }
# ]
# [label_id: 0
# score: 0.94769484
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48354012
#     ymin: 0.33577722
#     width: 0.17828202
#     height: 0.2377091
#   }
#   relative_keypoints {
#     x: 0.53061813
#     y: 0.4092452
#   }
#   relative_keypoints {
#     x: 0.60897833
#     y: 0.38115984
#   }
#   relative_keypoints {
#     x: 0.58172035
#     y: 0.44218057
#   }
#   relative_keypoints {
#     x: 0.59073126
#     y: 0.49647188
#   }
#   relative_keypoints {
#     x: 0.48753616
#     y: 0.4596361
#   }
#   relative_keypoints {
#     x: 0.6554595
#     y: 0.40034527
#   }
# }
# ]
# [label_id: 0
# score: 0.9109595
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48136517
#     ymin: 0.32704914
#     width: 0.19842246
#     height: 0.2645632
#   }
#   relative_keypoints {
#     x: 0.53544235
#     y: 0.41684943
#   }
#   relative_keypoints {
#     x: 0.6176695
#     y: 0.39062077
#   }
#   relative_keypoints {
#     x: 0.58772194
#     y: 0.46605712
#   }
#   relative_keypoints {
#     x: 0.5963008
#     y: 0.5201959
#   }
#   relative_keypoints {
#     x: 0.4913318
#     y: 0.45330447
#   }
#   relative_keypoints {
#     x: 0.6675944
#     y: 0.39746088
#   }
# }
# ]
# [label_id: 0
# score: 0.9109595
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48136517
#     ymin: 0.32704914
#     width: 0.19842246
#     height: 0.2645632
#   }
#   relative_keypoints {
#     x: 0.53544235
#     y: 0.41684943
#   }
#   relative_keypoints {
#     x: 0.6176695
#     y: 0.39062077
#   }
#   relative_keypoints {
#     x: 0.58772194
#     y: 0.46605712
#   }
#   relative_keypoints {
#     x: 0.5963008
#     y: 0.5201959
#   }
#   relative_keypoints {
#     x: 0.4913318
#     y: 0.45330447
#   }
#   relative_keypoints {
#     x: 0.6675944
#     y: 0.39746088
#   }
# }
# ]
# [label_id: 0
# score: 0.9109595
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48136517
#     ymin: 0.32704914
#     width: 0.19842246
#     height: 0.2645632
#   }
#   relative_keypoints {
#     x: 0.53544235
#     y: 0.41684943
#   }
#   relative_keypoints {
#     x: 0.6176695
#     y: 0.39062077
#   }
#   relative_keypoints {
#     x: 0.58772194
#     y: 0.46605712
#   }
#   relative_keypoints {
#     x: 0.5963008
#     y: 0.5201959
#   }
#   relative_keypoints {
#     x: 0.4913318
#     y: 0.45330447
#   }
#   relative_keypoints {
#     x: 0.6675944
#     y: 0.39746088
#   }
# }
# ]
# [label_id: 0
# score: 0.9109595
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48136517
#     ymin: 0.32704914
#     width: 0.19842246
#     height: 0.2645632
#   }
#   relative_keypoints {
#     x: 0.53544235
#     y: 0.41684943
#   }
#   relative_keypoints {
#     x: 0.6176695
#     y: 0.39062077
#   }
#   relative_keypoints {
#     x: 0.58772194
#     y: 0.46605712
#   }
#   relative_keypoints {
#     x: 0.5963008
#     y: 0.5201959
#   }
#   relative_keypoints {
#     x: 0.4913318
#     y: 0.45330447
#   }
#   relative_keypoints {
#     x: 0.6675944
#     y: 0.39746088
#   }
# }
# ]
# [label_id: 0
# score: 0.8840942
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4870937
#     ymin: 0.3479696
#     width: 0.18923563
#     height: 0.25231433
#   }
#   relative_keypoints {
#     x: 0.5517928
#     y: 0.43403333
#   }
#   relative_keypoints {
#     x: 0.6298129
#     y: 0.41109514
#   }
#   relative_keypoints {
#     x: 0.6126402
#     y: 0.4819451
#   }
#   relative_keypoints {
#     x: 0.61640835
#     y: 0.53257847
#   }
#   relative_keypoints {
#     x: 0.49150363
#     y: 0.46588182
#   }
#   relative_keypoints {
#     x: 0.66109365
#     y: 0.41331917
#   }
# }
# ]
# [label_id: 0
# score: 0.8840942
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4870937
#     ymin: 0.3479696
#     width: 0.18923563
#     height: 0.25231433
#   }
#   relative_keypoints {
#     x: 0.5517928
#     y: 0.43403333
#   }
#   relative_keypoints {
#     x: 0.6298129
#     y: 0.41109514
#   }
#   relative_keypoints {
#     x: 0.6126402
#     y: 0.4819451
#   }
#   relative_keypoints {
#     x: 0.61640835
#     y: 0.53257847
#   }
#   relative_keypoints {
#     x: 0.49150363
#     y: 0.46588182
#   }
#   relative_keypoints {
#     x: 0.66109365
#     y: 0.41331917
#   }
# }
# ]
# [label_id: 0
# score: 0.8840942
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4870937
#     ymin: 0.3479696
#     width: 0.18923563
#     height: 0.25231433
#   }
#   relative_keypoints {
#     x: 0.5517928
#     y: 0.43403333
#   }
#   relative_keypoints {
#     x: 0.6298129
#     y: 0.41109514
#   }
#   relative_keypoints {
#     x: 0.6126402
#     y: 0.4819451
#   }
#   relative_keypoints {
#     x: 0.61640835
#     y: 0.53257847
#   }
#   relative_keypoints {
#     x: 0.49150363
#     y: 0.46588182
#   }
#   relative_keypoints {
#     x: 0.66109365
#     y: 0.41331917
#   }
# }
# ]
# [label_id: 0
# score: 0.8840942
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4870937
#     ymin: 0.3479696
#     width: 0.18923563
#     height: 0.25231433
#   }
#   relative_keypoints {
#     x: 0.5517928
#     y: 0.43403333
#   }
#   relative_keypoints {
#     x: 0.6298129
#     y: 0.41109514
#   }
#   relative_keypoints {
#     x: 0.6126402
#     y: 0.4819451
#   }
#   relative_keypoints {
#     x: 0.61640835
#     y: 0.53257847
#   }
#   relative_keypoints {
#     x: 0.49150363
#     y: 0.46588182
#   }
#   relative_keypoints {
#     x: 0.66109365
#     y: 0.41331917
#   }
# }
# ]
# [label_id: 0
# score: 0.8998774
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48245454
#     ymin: 0.34182566
#     width: 0.20455813
#     height: 0.27274442
#   }
#   relative_keypoints {
#     x: 0.5575248
#     y: 0.43343645
#   }
#   relative_keypoints {
#     x: 0.64321774
#     y: 0.41025275
#   }
#   relative_keypoints {
#     x: 0.62736523
#     y: 0.48588365
#   }
#   relative_keypoints {
#     x: 0.62822515
#     y: 0.5403376
#   }
#   relative_keypoints {
#     x: 0.48301458
#     y: 0.4673599
#   }
#   relative_keypoints {
#     x: 0.669364
#     y: 0.4145605
#   }
# }
# ]
# [label_id: 0
# score: 0.8998774
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48245454
#     ymin: 0.34182566
#     width: 0.20455813
#     height: 0.27274442
#   }
#   relative_keypoints {
#     x: 0.5575248
#     y: 0.43343645
#   }
#   relative_keypoints {
#     x: 0.64321774
#     y: 0.41025275
#   }
#   relative_keypoints {
#     x: 0.62736523
#     y: 0.48588365
#   }
#   relative_keypoints {
#     x: 0.62822515
#     y: 0.5403376
#   }
#   relative_keypoints {
#     x: 0.48301458
#     y: 0.4673599
#   }
#   relative_keypoints {
#     x: 0.669364
#     y: 0.4145605
#   }
# }
# ]
# [label_id: 0
# score: 0.8998774
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48245454
#     ymin: 0.34182566
#     width: 0.20455813
#     height: 0.27274442
#   }
#   relative_keypoints {
#     x: 0.5575248
#     y: 0.43343645
#   }
#   relative_keypoints {
#     x: 0.64321774
#     y: 0.41025275
#   }
#   relative_keypoints {
#     x: 0.62736523
#     y: 0.48588365
#   }
#   relative_keypoints {
#     x: 0.62822515
#     y: 0.5403376
#   }
#   relative_keypoints {
#     x: 0.48301458
#     y: 0.4673599
#   }
#   relative_keypoints {
#     x: 0.669364
#     y: 0.4145605
#   }
# }
# ]
# [label_id: 0
# score: 0.8998774
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48245454
#     ymin: 0.34182566
#     width: 0.20455813
#     height: 0.27274442
#   }
#   relative_keypoints {
#     x: 0.5575248
#     y: 0.43343645
#   }
#   relative_keypoints {
#     x: 0.64321774
#     y: 0.41025275
#   }
#   relative_keypoints {
#     x: 0.62736523
#     y: 0.48588365
#   }
#   relative_keypoints {
#     x: 0.62822515
#     y: 0.5403376
#   }
#   relative_keypoints {
#     x: 0.48301458
#     y: 0.4673599
#   }
#   relative_keypoints {
#     x: 0.669364
#     y: 0.4145605
#   }
# }
# ]
# [label_id: 0
# score: 0.9248217
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4874126
#     ymin: 0.3461674
#     width: 0.2011703
#     height: 0.26822704
#   }
#   relative_keypoints {
#     x: 0.5600482
#     y: 0.43464988
#   }
#   relative_keypoints {
#     x: 0.64495695
#     y: 0.41284895
#   }
#   relative_keypoints {
#     x: 0.62889487
#     y: 0.4871028
#   }
#   relative_keypoints {
#     x: 0.6299961
#     y: 0.5406678
#   }
#   relative_keypoints {
#     x: 0.48789442
#     y: 0.4691894
#   }
#   relative_keypoints {
#     x: 0.6721424
#     y: 0.4183281
#   }
# }
# ]
# [label_id: 0
# score: 0.9248217
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4874126
#     ymin: 0.3461674
#     width: 0.2011703
#     height: 0.26822704
#   }
#   relative_keypoints {
#     x: 0.5600482
#     y: 0.43464988
#   }
#   relative_keypoints {
#     x: 0.64495695
#     y: 0.41284895
#   }
#   relative_keypoints {
#     x: 0.62889487
#     y: 0.4871028
#   }
#   relative_keypoints {
#     x: 0.6299961
#     y: 0.5406678
#   }
#   relative_keypoints {
#     x: 0.48789442
#     y: 0.4691894
#   }
#   relative_keypoints {
#     x: 0.6721424
#     y: 0.4183281
#   }
# }
# ]
# [label_id: 0
# score: 0.9248217
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4874126
#     ymin: 0.3461674
#     width: 0.2011703
#     height: 0.26822704
#   }
#   relative_keypoints {
#     x: 0.5600482
#     y: 0.43464988
#   }
#   relative_keypoints {
#     x: 0.64495695
#     y: 0.41284895
#   }
#   relative_keypoints {
#     x: 0.62889487
#     y: 0.4871028
#   }
#   relative_keypoints {
#     x: 0.6299961
#     y: 0.5406678
#   }
#   relative_keypoints {
#     x: 0.48789442
#     y: 0.4691894
#   }
#   relative_keypoints {
#     x: 0.6721424
#     y: 0.4183281
#   }
# }
# ]
